-- %% [markdown]
-- **Closed Deals Stream**

-- %%
CREATE OR REFRESH STREAMING TABLE bde2026.bronze.closed_deals_stream 
  TBLPROPERTIES (
    'delta.enableChangeDataFeed' = 'true'   -- Defined directly inside the schema definition!
  )
AS
SELECT *,_metadata.file_path as source_file_path,_metadata.file_modification_time as source_file_modification_time,
_metadata.file_size as source_file_size,current_timestamp() as ingestion_timestamp,current_user() as ingestion_user 
FROM  cloud_files('abfss://bde2026@deacourseextdl574.dfs.core.windows.net/landing/closed_deals/',
'csv',
map('cloudFiles.inferColumnTypes', 'true', 
    'header', 'true',
    'delimiter',','));
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>message</th></tr></thead><tbody><tr><td>This Delta Live Tables query is syntactically valid, but you must create a pipeline in order to define and populate your table.</td></tr></tbody></table></div>

-- %% [markdown]
-- **Customers Stream**

-- %%
CREATE OR REFRESH STREAMING TABLE bde2026.bronze.customers_stream AS
SELECT *,_metadata.file_path as source_file_path,_metadata.file_modification_time as source_file_modification_time,
_metadata.file_size as source_file_size,current_timestamp() as ingestion_timestamp,current_user() as ingestion_user 
from cloud_files('abfss://bde2026@deacourseextdl574.dfs.core.windows.net/landing/customers/',
'csv',
map('cloudFiles.inferColumnTypes', 'true', 
    'header', 'true',
    'delimiter',','));
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>message</th></tr></thead><tbody><tr><td>This Delta Live Tables query is syntactically valid, but you must create a pipeline in order to define and populate your table.</td></tr></tbody></table></div>

-- %% [markdown]
-- **Geolocation Stream**

-- %%
CREATE OR REFRESH STREAMING TABLE bde2026.bronze.geolocation_stream AS
SELECT *,_metadata.file_path as source_file_path,_metadata.file_modification_time as source_file_modification_time,
_metadata.file_size as source_file_size,current_timestamp() as ingestion_timestamp,current_user() as ingestion_user  
from cloud_files('abfss://bde2026@deacourseextdl574.dfs.core.windows.net/landing/geolocation/',
'csv',
map('cloudFiles.inferColumnTypes', 'true', 
    'header', 'true',
    'delimiter',','));
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>message</th></tr></thead><tbody><tr><td>This Delta Live Tables query is syntactically valid, but you must create a pipeline in order to define and populate your table.</td></tr></tbody></table></div>

-- %% [markdown]
-- **Order Items Stream**

-- %%
CREATE OR REFRESH STREAMING TABLE bde2026.bronze.order_items_stream 
TBLPROPERTIES (
    'delta.enableChangeDataFeed' = 'true'   -- Defined directly inside the schema definition!
  )
AS
SELECT *,_metadata.file_path as source_file_path,_metadata.file_modification_time as source_file_modification_time,
_metadata.file_size as source_file_size,current_timestamp() as ingestion_timestamp,current_user() as ingestion_user 
from cloud_files('abfss://bde2026@deacourseextdl574.dfs.core.windows.net/landing/items/',
'csv',
map('cloudFiles.inferColumnTypes', 'true', 
    'header', 'true',
    'delimiter',','));
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>message</th></tr></thead><tbody><tr><td>This Delta Live Tables query is syntactically valid, but you must create a pipeline in order to define and populate your table.</td></tr></tbody></table></div>

-- %% [markdown]
-- **Order Payments Stream**

-- %%
CREATE OR REFRESH STREAMING TABLE bde2026.bronze.order_payments_stream 
TBLPROPERTIES (
    'delta.enableChangeDataFeed' = 'true'   -- Defined directly inside the schema definition!
  )
AS
SELECT *,_metadata.file_path as source_file_path,_metadata.file_modification_time as source_file_modification_time,
_metadata.file_size as source_file_size,current_timestamp() as ingestion_timestamp,current_user() as ingestion_user 
from cloud_files('abfss://bde2026@deacourseextdl574.dfs.core.windows.net/landing/payments/',
'csv',
map('cloudFiles.inferColumnTypes', 'true', 
    'header', 'true',
    'delimiter',','));
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>message</th></tr></thead><tbody><tr><td>This Delta Live Tables query is syntactically valid, but you must create a pipeline in order to define and populate your table.</td></tr></tbody></table></div>

-- %% [markdown]
-- **Order Reviews Stream**

-- %%
CREATE OR REFRESH STREAMING TABLE bde2026.bronze.order_reviews_stream 
TBLPROPERTIES (
    'delta.enableChangeDataFeed' = 'true'   -- Defined directly inside the schema definition!
  )
AS
SELECT *,_metadata.file_path as source_file_path,_metadata.file_modification_time as source_file_modification_time,
_metadata.file_size as source_file_size,current_timestamp() as ingestion_timestamp,current_user() as ingestion_user 
from cloud_files('abfss://bde2026@deacourseextdl574.dfs.core.windows.net/landing/reviews/',
'csv',
map('cloudFiles.inferColumnTypes', 'true', 
    'header', 'true',
    'delimiter',','));
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>message</th></tr></thead><tbody><tr><td>This Delta Live Tables query is syntactically valid, but you must create a pipeline in order to define and populate your table.</td></tr></tbody></table></div>

-- %% [markdown]
-- **Orders Stream**

-- %%
CREATE OR REFRESH STREAMING TABLE bde2026.bronze.orders_stream 
TBLPROPERTIES (
    'delta.enableChangeDataFeed' = 'true'   -- Defined directly inside the schema definition!
  )
AS
SELECT *,_metadata.file_path as source_file_path,_metadata.file_modification_time as source_file_modification_time,
_metadata.file_size as source_file_size,current_timestamp() as ingestion_timestamp,current_user() as ingestion_user
from cloud_files('abfss://bde2026@deacourseextdl574.dfs.core.windows.net/landing/orders/',
'csv',
map('cloudFiles.inferColumnTypes', 'true', 
    'header', 'true',
    'delimiter',','));
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>message</th></tr></thead><tbody><tr><td>This Delta Live Tables query is syntactically valid, but you must create a pipeline in order to define and populate your table.</td></tr></tbody></table></div>

-- %% [markdown]
-- **Products Stream**

-- %%
CREATE OR REFRESH STREAMING TABLE bde2026.bronze.products_stream 
TBLPROPERTIES (
    'delta.enableChangeDataFeed' = 'true'   -- Defined directly inside the schema definition!
  )
AS
SELECT *,_metadata.file_path as source_file_path,_metadata.file_modification_time as source_file_modification_time,
_metadata.file_size as source_file_size,current_timestamp() as ingestion_timestamp,current_user() as ingestion_user 
from cloud_files('abfss://bde2026@deacourseextdl574.dfs.core.windows.net/landing/products/',
'csv',
map('cloudFiles.inferColumnTypes', 'true', 
    'header', 'true',
    'delimiter',','));
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>message</th></tr></thead><tbody><tr><td>This Delta Live Tables query is syntactically valid, but you must create a pipeline in order to define and populate your table.</td></tr></tbody></table></div>

-- %% [markdown]
-- **Sellers Stream**

-- %%
CREATE OR REFRESH STREAMING TABLE bde2026.bronze.sellers_stream 
TBLPROPERTIES (
    'delta.enableChangeDataFeed' = 'true'   -- Defined directly inside the schema definition!
  )
AS
SELECT *,_metadata.file_path as source_file_path,_metadata.file_modification_time as source_file_modification_time,
_metadata.file_size as source_file_size,current_timestamp() as ingestion_timestamp,current_user() as ingestion_user 
from cloud_files('abfss://bde2026@deacourseextdl574.dfs.core.windows.net/landing/sellers',
'csv',
map('cloudFiles.inferColumnTypes', 'true', 
    'header', 'true',
    'delimiter',','));
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>message</th></tr></thead><tbody><tr><td>This Delta Live Tables query is syntactically valid, but you must create a pipeline in order to define and populate your table.</td></tr></tbody></table></div>

-- %% [markdown]
-- **Translation Stream**

-- %%
CREATE OR REFRESH STREAMING TABLE bde2026.bronze.translation_stream 
TBLPROPERTIES (
    'delta.enableChangeDataFeed' = 'true'   -- Defined directly inside the schema definition!
  )
AS
SELECT *,_metadata.file_path as source_file_path,_metadata.file_modification_time as source_file_modification_time,
_metadata.file_size as source_file_size,current_timestamp() as ingestion_timestamp,current_user() as ingestion_user  
from cloud_files('abfss://bde2026@deacourseextdl574.dfs.core.windows.net/landing/translation/',
'csv',
map('cloudFiles.inferColumnTypes', 'true', 
    'header', 'true',
    'delimiter',','));
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>message</th></tr></thead><tbody><tr><td>This Delta Live Tables query is syntactically valid, but you must create a pipeline in order to define and populate your table.</td></tr></tbody></table></div>
