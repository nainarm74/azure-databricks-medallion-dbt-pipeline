-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS dea_course_ext_dl574_bde2026
URL 'abfss://bde2026@deacourseextdl574.dfs.core.windows.net'
WITH (STORAGE CREDENTIAL dea_course_ext_scr)
COMMENT "External data lake storage location for bde2026 SCTP project"

-- %%
%fs ls 'abfss://bde2026@deacourseextdl574.dfs.core.windows.net/'
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
-- Create the Catalog - gimobox

show catalogs
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>catalog</th></tr></thead><tbody><tr><td>__databricks_internal</td></tr><tr><td>asql_gizmobox_db_catalog_sql</td></tr><tr><td>asql_gizmobox_db_catalog_ui</td></tr><tr><td>circuitbox</td></tr><tr><td>dea_course_ws</td></tr><tr><td>demo</td></tr><tr><td>gizmobox</td></tr><tr><td>samples</td></tr><tr><td>system</td></tr></tbody></table></div>

-- %%
CREATE CATALOG IF NOT EXISTS bde2026 
MANAGED LOCATION 'abfss://bde2026@deacourseextdl574.dfs.core.windows.net'
COMMENT 'bde2026 catalog'

-- %%
-- Create Schemas Landing, Bronze, Silver and Gold
USE CATALOG bde2026;
Select current_catalog()
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_catalog()</th></tr></thead><tbody><tr><td>bde2026</td></tr></tbody></table></div>

-- %%
USE CATALOG bde2026;

CREATE SCHEMA IF NOT EXISTS landing
MANAGED LOCATION 'abfss://bde2026@deacourseextdl574.dfs.core.windows.net/landing'
COMMENT 'landing schema';

CREATE SCHEMA IF NOT EXISTS bronze
MANAGED LOCATION 'abfss://bde2026@deacourseextdl574.dfs.core.windows.net/bronze'
COMMENT 'bronze schema';

CREATE SCHEMA IF NOT EXISTS silver
MANAGED LOCATION 'abfss://bde2026@deacourseextdl574.dfs.core.windows.net/silver'
COMMENT 'silver schema';

CREATE SCHEMA IF NOT EXISTS gold 
MANAGED LOCATION 'abfss://bde2026@deacourseextdl574.dfs.core.windows.net/gold'
COMMENT 'gold schema';
-- Create the table in the bronze schema
USE CATALOG bde2026;

-- %%
USE CATALOG bde2026;  
SHOW SCHEMAS;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>bronze</td></tr><tr><td>default</td></tr><tr><td>gold</td></tr><tr><td>information_schema</td></tr><tr><td>landing</td></tr><tr><td>silver</td></tr><tr><td>silver_silver</td></tr></tbody></table></div>
